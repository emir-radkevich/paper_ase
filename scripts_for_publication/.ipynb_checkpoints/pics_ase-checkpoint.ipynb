# %%
# Импортируем все необходиме модули
# pandas -- для создания датафреймов, как в r, в питоне
# os -- для того, чтобы обращаться к папкам и вообще работать с файловой системой
# seaborn -- для того, чтобы делать красивые картинки
# matplotlib -- этот модуль нужен для seaborn

import numpy as np
import pandas as pd
import os

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 10)

# %%
# Напишем функцию, которая будет загружать наш датасет и добавлять необходимые
# колонки для построения графика

def make_proper_df(df_name):
    # Смотрим, где мы
    where_am_i = os.getcwd()
    
    # Грузим в df наш датасет
    df = pd.read_csv(os.path.join(where_am_i, 'tsv_files', df_name), sep='\t')
    
    # Добавляем в наш df четыре столбика
    # ase_normal -- процент АСЭ генов в норме
    # ase_tumor -- процент АСЭ генов в опухоли
    # total_percent -- по сути везде пишется 100 % (это нужно для построения графика, 
    # никакой смысловой нагрузки этот столик не несет)
    # total_count -- количество образцов (и нормы, и опухоли), которые тестировали
    df['ase_freq_normal'] = df.count_normal/df.total_normal * 100
    df['ase_freq_tumor'] = df.count_tumor/df.total_tumor * 100
    df['total_percent'] = df.total_normal/df.total_normal * 100
    df['total_count'] = df.total_normal + df.total_tumor
    
    df.rename(columns={'median_normal':'maf_median_normal'}, inplace=True)
    df.rename(columns={'median_tumor':'maf_median_tumor'}, inplace=True)
    df.rename(columns={'average_normal':'maf_average_normal'}, inplace=True)
    df.rename(columns={'average_tumor':'maf_average_tumor'}, inplace=True)
    df.rename(columns={'stdev_normal':'maf_stdev_normal'}, inplace=True)
    df.rename(columns={'stdev_tumor':'maf_stdev_tumor'}, inplace=True)
    
    return df

# %%
# Грузим список наших генов
df = make_proper_df('statistics_ext.tsv')
df
# Out:
#        gene  maf_average_normal  maf_median_normal  maf_stdev_normal  \
# 0      A1BG            0.530000              0.530          0.000651
# 1      A1CF            0.800000              0.860          0.111923
# 2    ABCB11            0.650000              0.610          0.110131
# 3     ABCB4            0.620000              0.620               NaN
# 4    ACOT12            0.730000              0.730               NaN
# ..      ...                 ...                ...               ...
# 252     WRN            0.880000              0.880               NaN
# 253     XPC            0.715000              0.715          0.035355
# 254   YWHAE            0.876667              0.885          0.033862
# 255   ZFHX3            0.850000              0.850               NaN
# 256  ZNF331            0.826667              0.880          0.101160
#
#      count_normal  total_normal  maf_average_tumor  maf_median_tumor  \
# 0               2             6           0.640000             0.640
# 1               8            46           0.720000             0.690
# 2               5            30           0.650000             0.650
# 3               1            36           0.810000             0.810
# 4               1            11           0.840000             0.840
# ..            ...           ...                ...               ...
# 252             1            25           0.815000             0.815
# 253             2            74           0.749091             0.760
# 254             6            17           0.781667             0.810
# 255             1            38           0.767143             0.750
# 256             3             5           0.831000             0.840
#
#      maf_stdev_tumor  count_tumor  total_tumor  ase_freq_normal  \
# 0           0.039325            4            6        33.333333
# 1           0.091922            8           41        17.391304
# 2           0.036160            6           30        16.666667
# 3           0.088890            3           36         2.777778
# 4           0.023768            2           11         9.090909
# ..               ...          ...          ...              ...
# 252         0.035355            2           30         4.000000
# 253         0.076479           11           71         2.702703
# 254         0.120236            6           16        35.294118
# 255         0.052509            7           58         2.631579
# 256         0.043063           10           22        60.000000
#
#      ase_freq_tumor  total_percent  total_count
# 0         66.666667          100.0           12
# 1         19.512195          100.0           87
# 2         20.000000          100.0           60
# 3          8.333333          100.0           72
# 4         18.181818          100.0           22
# ..              ...            ...          ...
# 252        6.666667          100.0           55
# 253       15.492958          100.0          145
# 254       37.500000          100.0           33
# 255       12.068966          100.0           96
# 256       45.454545          100.0           27
#
# [257 rows x 15 columns]

# %%
# Грузим сегментрано дуплицированные гены
where_am_i = os.getcwd()
pic_path = os.path.abspath(os.path.join(where_am_i, '..', 'pics_for_publication'))

df_segm_dupl = pd.read_csv(os.path.join(where_am_i, 'tsv_files', 'segm_dupl.tsv'), sep='\t')

# %%
# Тут перечислены все гены, которые не являются супер дуплицированными
df_nsd = df.query("gene not in @df_segm_dupl.gene")
df_nsd = df_nsd.reset_index(drop=True)
df_nsd
# Out:
#        gene  maf_average_normal  maf_median_normal  maf_stdev_normal  \
# 0      A1BG            0.530000              0.530          0.000651
# 1      A1CF            0.800000              0.860          0.111923
# 2    ABCB11            0.650000              0.610          0.110131
# 3     ABCB4            0.620000              0.620               NaN
# 4    ACOT12            0.730000              0.730               NaN
# ..      ...                 ...                ...               ...
# 204     VTN            0.810000              0.860          0.116074
# 205     XPC            0.715000              0.715          0.035355
# 206   YWHAE            0.876667              0.885          0.033862
# 207   ZFHX3            0.850000              0.850               NaN
# 208  ZNF331            0.826667              0.880          0.101160
#
#      count_normal  total_normal  maf_average_tumor  maf_median_tumor  \
# 0               2             6           0.640000              0.64
# 1               8            46           0.720000              0.69
# 2               5            30           0.650000              0.65
# 3               1            36           0.810000              0.81
# 4               1            11           0.840000              0.84
# ..            ...           ...                ...               ...
# 204             9            14           0.790000              0.85
# 205             2            74           0.749091              0.76
# 206             6            17           0.781667              0.81
# 207             1            38           0.767143              0.75
# 208             3             5           0.831000              0.84
#
#      maf_stdev_tumor  count_tumor  total_tumor  ase_freq_normal  \
# 0           0.039325            4            6        33.333333
# 1           0.091922            8           41        17.391304
# 2           0.036160            6           30        16.666667
# 3           0.088890            3           36         2.777778
# 4           0.023768            2           11         9.090909
# ..               ...          ...          ...              ...
# 204         0.124429            9           14        64.285714
# 205         0.076479           11           71         2.702703
# 206         0.120236            6           16        35.294118
# 207         0.052509            7           58         2.631579
# 208         0.043063           10           22        60.000000
#
#      ase_freq_tumor  total_percent  total_count
# 0         66.666667          100.0           12
# 1         19.512195          100.0           87
# 2         20.000000          100.0           60
# 3          8.333333          100.0           72
# 4         18.181818          100.0           22
# ..              ...            ...          ...
# 204       64.285714          100.0           28
# 205       15.492958          100.0          145
# 206       37.500000          100.0           33
# 207       12.068966          100.0           96
# 208       45.454545          100.0           27
#
# [209 rows x 15 columns]

# %%
# Тут перечислены все гены, для которых показан геномный импринтинг
# взял с geneimprint.com
df_imprinted = pd.read_csv(os.path.join(where_am_i, 'tsv_files', 'imprinted_genes.tsv'))
df_imprinted
# Out:
#               Gene
# 0           DIRAS3
# 1          RNU5D-1
# 2             TP73
# 3           LRRTM1
# 4             GPR1
# ..             ...
# 446   dJ806M20.3.3
# 447         KVLQT1
# 448  DKFZp686C0927
# 449  DKFZp761I1912
# 450       FLJ26167
#
# [451 rows x 1 columns]

# %%
# Потенциально импринтированные гены
df_nsd_imp = df_nsd.query("gene in @df_imprinted.Gene")
df_nsd_imp = df_nsd_imp.reset_index(drop=True)
df_nsd_imp
# Out:
#    gene  maf_average_normal  maf_median_normal  maf_stdev_normal  \
# 0  GNAS                0.83               0.83          0.058788
#
#    count_normal  total_normal  maf_average_tumor  maf_median_tumor  \
# 0             2            37               0.73              0.72
#
#    maf_stdev_tumor  count_tumor  total_tumor  ase_freq_normal  ase_freq_tumor  \
# 0         0.069433           12           38         5.405405       31.578947
#
#    total_percent  total_count
# 0          100.0           75

# %%
pd.set_option('display.max_rows', 120)

df_trial = df_nsd.query('(total_normal > 7) & (total_tumor > 7) & \
    (ase_freq_normal < 100) & (ase_freq_tumor < 100) & (count_normal > 2) & (count_tumor > 2)')
df_trial = df_trial.reset_index(drop=True)
df_trial
# Out:
#            gene  maf_average_normal  maf_median_normal  maf_stdev_normal  \
# 0          A1CF            0.800000              0.860          0.111923
# 1        ABCB11            0.650000              0.610          0.110131
# 2         ADH1A            0.800000              0.810          0.075667
# 3          ADH6            0.590000              0.570          0.041170
# 4          AGXT            0.560000              0.560          0.020718
# 5          AHSG            0.560000              0.550          0.025118
# 6        AKR1C4            0.640000              0.640          0.050094
# 7        AKR1D1            0.620000              0.640          0.050202
# 8           ALB            0.720000              0.720          0.129981
# 9           ANG            0.630000              0.630          0.011067
# 10          APC            0.794000              0.840          0.101882
# 11         APCS            0.580000              0.580          0.048774
# 12        APOA5            0.570000              0.570          0.021585
# 13        APOC1            0.550000              0.540          0.024748
# 14        APOC3            0.540000              0.540          0.017380
# 15        APOC4            0.630000              0.610          0.066887
# 16         APOH            0.550000              0.540          0.046708
# 17    ARHGEF10L            0.786667              0.840          0.092376
# 18     ARHGEF12            0.860000              0.860          0.020000
# 19        ASGR2            0.850000              0.870          0.037268
# 20          ATM            0.857500              0.865          0.028723
# 21       ATP1A1            0.820000              0.880          0.129504
# 22         BAAT            0.570000              0.540          0.085769
# 23         BDH1            0.640000              0.630          0.039598
# 24        BIRC6            0.790000              0.830          0.078187
# 25           C5            0.660000              0.570          0.132268
# 26          C8A            0.570000              0.570          0.030238
# 27          C8B            0.570000              0.570          0.024524
# 28           C9            0.580000              0.560          0.044715
# 29        CCL16            0.830000              0.870          0.063827
# 30         CD74            0.780000              0.780          0.051677
# 31          CFB            0.610000              0.570          0.098621
# 32        CFHR5            0.670000              0.680          0.038292
# 33         CHD2            0.810000              0.800          0.065574
# 34         CHD4            0.780000              0.860          0.127167
# 35         CLTC            0.872857              0.880          0.023604
# 36         CPB2            0.560000              0.550          0.030074
# 37         CPN2            0.580000              0.570          0.040505
# 38   CTB-96E2.2            0.530000              0.530          0.006066
# 39       CYP2C9            0.660000              0.550          0.163378
# 40       CYP2E1            0.610000              0.560          0.104846
# 41       CYP8B1            0.600000              0.600          0.036523
# 42        EIF3E            0.869000              0.880          0.024244
sns.distplot(df_trial["ase_freq_tumor"], hist=False, color="r", kde_kws={"shade": True}, label="$ASE_{опухоль}$")
ax.set(xlabel="ASE")
sns.despine()
plt.savefig(os.path.join(pic_path, 'ase_dist.png'), dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Посмотрим на онкогены.

# %%
df_onc = pd.read_csv(os.path.join(os.getcwd(), 'tsv_files', "onc_37.tsv"), sep='\t')

# %%
df_onc_sort = df_trial.query("gene in @df_onc.gene_name")
df_onc_sort = df_onc_sort.reset_index(drop=True)
df_onc_sort
# Out:
#      gene  maf_average_normal  maf_median_normal  maf_stdev_normal  \
# 0    A1CF                0.80               0.86          0.111923
# 1  ATP1A1                0.82               0.88          0.129504
# 2   BIRC6                0.79               0.83          0.078187
# 3    CD74                0.78               0.78          0.051677
# 4    CHD4                0.78               0.86          0.127167
# 5   EPAS1                0.83               0.84          0.050089
# 6   ERBB3                0.75               0.70          0.105592
# 7     MET                0.68               0.65          0.094216
# 8    SND1                0.82               0.82          0.048265
#
#    count_normal  total_normal  maf_average_tumor  maf_median_tumor  \
# 0             8            46               0.72              0.69
# 1             4            18               0.79              0.86
# 2             9            78               0.76              0.75
# 3            20            30               0.79              0.78
# 4             5            33               0.80              0.84
# 5             7            30               0.76              0.77
# 6             6            73               0.71              0.70
# 7             7            50               0.74              0.78
# 8             5            51               0.77              0.81
#
#    maf_stdev_tumor  count_tumor  total_tumor  ase_freq_normal  ase_freq_tumor  \
# 0         0.091922            8           41        17.391304       19.512195
# 1         0.133422            6           16        22.222222       37.500000
# 2         0.081678           18           75        11.538462       24.000000
# 3         0.049925           21           31        66.666667       67.741935
# 4         0.107122           15           38        15.151515       39.473684
# 5         0.116441            6           24        23.333333       25.000000
# 6         0.063514           13           56         8.219178       23.214286
# 7         0.107420           12           49        14.000000       24.489796
# 8         0.078849           14           52         9.803922       26.923077
#
#    total_percent  total_count
# 0          100.0           87
# 1          100.0           34
# 2          100.0          153
# 3          100.0           61
# 4          100.0           71
# 5          100.0           54
# 6          100.0          129
# 7          100.0           99
# 8          100.0          103

# %%
df_trial_ren = df_trial.rename(columns={'ase_freq_normal':'$ASE_{норма}$'}, inplace=False)
df_trial_ren = df_trial_ren.rename(columns={'ase_freq_tumor':'$ASE_{опухоль}$'}, inplace=False)

sns.set(style="white")

cmap = sns.cubehelix_palette(rot=-.15, as_cmap=True)
sns.relplot(x="maf_median_normal", y="maf_median_tumor", 
            size='$ASE_{норма}$',
            hue='$ASE_{опухоль}$',
            sizes=(40, 400), alpha=.7, palette=cmap,
            data=df_trial_ren)._legend.remove()

plt.legend(bbox_to_anchor=(1,.75))
plt.xlabel("$MAF_{норма}$")
plt.ylabel("$MAF_{опухоль}$")

# for i in df_onc_sort.iterrows():
#     plt.text(i[1][2], i[1][7], str(i[1][0]), color="red", alpha=.8, fontsize=13)
# plt.savefig(os.path.join(pic_path, 'all_ase.png'), dpi=400, bbox_inches='tight')
# Out:
# Text(42.99690070800783, 0.5, '$MAF_{опухоль}$')

# %%
sns.set(style="whitegrid")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
sns.relplot(x="ase_freq_normal", y="ase_freq_tumor", 
            size='maf_median_tumor', 
            hue='maf_median_normal',
            sizes=(40, 400), alpha=.7, palette=cmap,
            data=df_trial)._legend.remove()
plt.legend(bbox_to_anchor=(1,.75))
plt.savefig(os.path.join(pic_path, 'all_maf.png'), dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Сделаем картинку, где будут отображены гены, где частота АСЭ в опухоли выше, чем в норме

# %%
# Это то, что будет оставлено в датасете

# (total_normal > 7) & (total_tumor > 7) -- количество образцов в норме и опухоли,
# которые подавали mbased, больше 7 (число из головы)

# (ase_tumor/ase_normal <= 2) -- частота АСЭ в опухоли в 2 раза и больше выше,
# чем в норме (просто хотел показать, что таких вариантов очень много)

# (ase_normal < 100) & (ase_tumor < 100) -- это проверка на то, чтобы количество
# АСЭ образцов было НЕ больше, чем тестируемых образцов (такое действительно есть!)

df_htase = df_nsd.query('(total_normal > 7) & (total_tumor > 7) & \
    (ase_freq_tumor/ase_freq_normal > 2) & (ase_freq_normal < 100) & (ase_freq_tumor < 100)')
df_htase = df_htase.reset_index(drop=True)
df_htase
# Out:
#          gene  maf_average_normal  maf_median_normal  maf_stdev_normal  \
# 0       ABCB4            0.620000              0.620               NaN
# 1        AKT1            0.870000              0.870               NaN
# 2        APCS            0.580000              0.580          0.048774
# 3   ARHGEF10L            0.786667              0.840          0.092376
# 4    ARHGEF12            0.860000              0.860          0.020000
# ..        ...                 ...                ...               ...
# 53       SPP2            0.620000              0.630          0.012191
# 54        TAT            0.580000              0.540          0.062847
# 55       TET2            0.850000              0.850               NaN
# 56        XPC            0.715000              0.715          0.035355
# 57      ZFHX3            0.850000              0.850               NaN
#
#     count_normal  total_normal  maf_average_tumor  maf_median_tumor  \
# 0              1            36           0.810000              0.81
# 1              1            33           0.870000              0.87
# 2              8            28           0.660000              0.62
# 3              3            52           0.815714              0.83
# 4              3            32           0.787143              0.82
# ..           ...           ...                ...               ...
# 53             3            19           0.610000              0.60
# 54             5            23           0.630000              0.59
# 55             1            37           0.785000              0.81
# 56             2            74           0.749091              0.76
# 57             1            38           0.767143              0.75
#
#     maf_stdev_tumor  count_tumor  total_tumor  ase_freq_normal  \
# 0          0.088890            3           36         2.777778
# 1          0.008571            2           30         3.030303
# 2          0.099754           21           28        28.571429
# 3          0.077858            7           45         5.769231
# 4          0.098609            7           33         9.375000
# ..              ...          ...          ...              ...
# 53         0.031605            7           19        15.789474
# 54         0.075908           11           23        21.739130
# 55         0.088129            4           41         2.702703
# 56         0.076479           11           71         2.702703
# 57         0.052509            7           58         2.631579
#
#     ase_freq_tumor  total_percent  total_count
# 0         8.333333          100.0           72
# 1         6.666667          100.0           63
# 2        75.000000          100.0           56
# 3        15.555556          100.0           97
# 4        21.212121          100.0           65
# ..             ...            ...          ...
# 53       36.842105          100.0           38
# 54       47.826087          100.0           46
# 55        9.756098          100.0           78
# 56       15.492958          100.0          145
# 57       12.068966          100.0           96
#
# [58 rows x 15 columns]

# %%
# Создаем картинку вида stacked barplot в seaborn

sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(5, 15))

sns.set_color_codes("pastel")
sns.barplot(x='total_percent', y="gene", data=df_htase,
            label="total", color="b")

sns.set_color_codes("muted")
sns.barplot(x='ase_freq_tumor', y="gene", data=df_htase,
            label="ase_freq_tumor", color='r')

sns.set_color_codes("muted")
sns.barplot(x="ase_freq_normal", y="gene", data = df_htase,
            label="ase_freq_normal", color="pink")

# ax.legend(ncol=1, loc="upper right", frameon=True)
ax.set(ylabel="gene",
       xlabel="fraction, %")
sns.despine(left=True, bottom=True)

plt.legend(bbox_to_anchor=(1, .6))
# plt.savefig(os.path.join(pic_path, 'high_tumor_ase_frequency.png'), dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Отсюда начинается код для нужных картинок

# %%
df_htase_sorted = df_htase.sort_values('ase_freq_tumor', ascending=False)

# %%
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(5, 15))

sns.set_color_codes("muted")
sns.barplot(x='ase_freq_tumor', y="gene", data=df_htase_sorted,
            label="$ASE_{опухоль}$", color='r')

sns.set_color_codes("muted")
sns.barplot(x="ase_freq_normal", y="gene", data = df_htase_sorted,
            label="$ASE_{норма}$", color="pink")

ax.set(ylabel="Ген",
       xlabel="Доля, %")
sns.despine()

ax.set_xlim([0,70])

plt.legend(bbox_to_anchor=(1.3, .5))
plt.savefig(os.path.join(pic_path, 'high_tumor_ase_frequency_pres.png'), dpi=400, bbox_inches='tight')

# %%
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(75, 10))

sns.set_color_codes("muted")
sns.barplot(y='ase_freq_tumor', x="gene", data=df_htase_sorted,
            label="ase_freq_tumor", color='r')

sns.set_color_codes("muted")
sns.barplot(y="ase_freq_normal", x="gene", data = df_htase_sorted,
            label="ase_freq_normal", color="pink")

ax.set(ylabel="fraction, %",
       xlabel="gene")
sns.despine(left=True, bottom=True)

plt.legend(bbox_to_anchor=(1, .6))
plt.savefig(os.path.join(pic_path, 'high_tumor_ase_frequency_vertical.png'), dpi=400, bbox_inches='tight')

# %% [markdown]
# ### А тут заканчивается

# %% [markdown]
# ### Гены, где частота АСЭ в норме выше, чем в опухоли

# %%
# Все гены, у которых (ase_normal/ase_tumor > 2)
df_hnase = df_nsd.query('(total_normal > 7) & (total_tumor > 7) & \
    (ase_freq_normal/ase_freq_tumor > 2) & (ase_freq_normal < 100) & (ase_freq_tumor < 100)')
df_hnase = df_hnase.reset_index(drop=True)
df_hnase
# Out:
#       gene  maf_average_normal  maf_median_normal  maf_stdev_normal  \
# 0    CASP8            0.850000              0.850               NaN
# 1      KDR            0.760000              0.770          0.097675
# 2    KLKB1            0.600000              0.590          0.024143
# 3  PPP2R1A            0.875000              0.875          0.021213
# 4    SMAD4            0.866667              0.880          0.023094
#
#    count_normal  total_normal  maf_average_tumor  maf_median_tumor  \
# 0             1             8               0.83              0.83
# 1             6            28               0.74              0.74
# 2             9            44               0.68              0.68
# 3             2             8               0.90              0.90
# 4             3            11               0.83              0.83
#
#    maf_stdev_tumor  count_tumor  total_tumor  ase_freq_normal  ase_freq_tumor  \
# 0              NaN            1           20        12.500000        5.000000
# 1         0.211471            2           21        21.428571        9.523810
# 2              NaN            1           44        20.454545        2.272727
# 3              NaN            1           11        25.000000        9.090909
# 4              NaN            1            9        27.272727       11.111111
#
#    total_percent  total_count
# 0          100.0           28
# 1          100.0           49
# 2          100.0           88
# 3          100.0           19
# 4          100.0           20

# %%
# Создаем картинку вида stacked barplot в seaborn

sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(3, 5))

sns.set_color_codes("muted")
sns.barplot(x='total_percent', y="gene", data=df_hnase,
            label="total", color="r")

sns.set_color_codes("pastel")
sns.barplot(x="ase_freq_normal", y="gene", data = df_hnase,
            label="ase_freq_normal", color="b")

sns.set_color_codes("muted")
sns.barplot(x='ase_freq_tumor', y="gene", data=df_hnase,
            label="ase_freq_tumor", color='pink')

# ax.legend(ncol=1, loc="upper right", frameon=True)
ax.set(ylabel="gene",
       xlabel="fraction, %")
sns.despine(left=True, bottom=True)

plt.legend(bbox_to_anchor=(1, .6))
# plt.savefig(os.path.join(pic_path, 'high_normal_ase_frequency.png'), dpi=400, bbox_inches='tight')

# %%
df_hnase_sorted = df_hnase.sort_values('ase_freq_normal', ascending=False)

# %%
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(3, 5))

sns.set_color_codes("muted")
sns.barplot(x='ase_freq_normal', y="gene", data=df_hnase_sorted,
            label="$ASE_{норма}$", color='pink')

sns.set_color_codes("muted")
sns.barplot(x="ase_freq_tumor", y="gene", data = df_hnase_sorted,
            label="$ASE_{опухоль}$", color="r")

ax.set(ylabel="Ген",
       xlabel="Доля, %")
sns.despine()

ax.set_xlim([0, 70])

plt.legend(bbox_to_anchor=(1.5, .6))
plt.savefig(os.path.join(pic_path, 'high_normal_ase_frequency_pres.png'), dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Теперь сделаем картинку, где отобразим все гены, у которых хотя бы в половине образцов наблюдается АСЭ (и в норме, и в опухоли) + частота АСЭ в опухоли выше, чем в норме

# %%
# Это то, что будет оставлено в датасете

# Большинство условий такие же, как в предыдущем условии
# (ase_tumor/ase_normal > 1.0) -- частота АСЭ в опухоли выше, чем в норме

# (count_normal/total_normal > 0.5) & (count_tumor/total_tumor > 0.5) -- 
# хотя бы в половине образцов наблюдается АСЭ (и в норме, и в опухоли)
 
df_hase = df_nsd.query('(total_normal > 7) & (total_tumor > 7) & (count_tumor/total_tumor > 0.5) & \
    (count_normal/total_normal > 0.5) & (ase_freq_normal < 100) & (ase_freq_tumor < 100) & \
    (ase_freq_tumor/ase_freq_normal > 1.0)')
df_hase = df_hase.reset_index(drop=True)
# df_hase

# %%
# Делаем картинку

sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(3, 7))

sns.set_color_codes("muted")
sns.barplot(x='total_percent', y="gene", data=df_hase,
            label="total", color="r")

sns.set_color_codes("muted")
sns.barplot(x='ase_freq_tumor', y="gene", data=df_hase,
            label="ase_freq_tumor", color='pink')

sns.set_color_codes("pastel")
sns.barplot(x="ase_freq_normal", y="gene", data = df_hase,
            label="ase_freq_normal", color="b")

# ax.legend(ncol=1, loc="upper right", frameon=True)
ax.set(ylabel="gene",
       xlabel="fraction, %")
sns.despine(left=True, bottom=True)

plt.legend(bbox_to_anchor=(1,.6))
plt.savefig(os.path.join(pic_path, 'high_ase_frequency.png'), dpi=400, bbox_inches='tight')
